# %%
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# %%
def get_title(soup):
    try:
        Title = soup.find("span", attrs={'class': 'B_NuCI'}).text
        
    except AttributeError:
        Titile=""
    return Title

def get_discount_price(soup):
    try:
        Discount_Price = soup.find("div", attrs={'class': '_30jeq3 _16Jk6d'}).text
        Discount_Price
    except AttributeError:
        Discounted_price = ""
    return Discount_Price

def get_original_price(soup):
    try:
        Original_Price = soup.find("div", attrs={'class': '_3I9_wc _2p6lqe'}).text
        Original_Price
    except AttributeError:
        Original_Price=""
    return Original_Price

def get_rating(soup):
    try:
        Rating=soup.find("div", attrs={'class': '_3LWZlK'}).text
    except AttributeError:
        Rating=""
    return Rating

def get_box_item(soup):
    try:
        Box_Item=soup.find('li',attrs={'class':'_21lJbe'}).text
    except AttributeError:
        Box_Item=""
    return Box_Item

# %%
if __name__ == '__main__':
    URL = "https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
    
    HEADER= ({ 'User-Agent':"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36" ,'Accept-Language': 'en-US,en;q=0.5' })
    
    WebPage=requests.get(URL,headers=HEADER)
    
    Soup =  BeautifulSoup(WebPage.content,"html.parser")
    
    Links = Soup.find_all("a", attrs={'class': '_1fQZEK'})
    
    
    
   
    Link_List=[]
    
    
    for link in Links:
        plink=link.get('href')
        Link_List.append(plink)
    
        
    dict = {"title":[], "discounted_price":[],"original_price":[], "rating":[], "box_item":[]}
    
    for link in Link_List:
        new_webpage = requests.get("https://www.flipkart.com" + link, headers=HEADER)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")
    
    
        dict['title'].append(get_title(new_soup))
        dict['discounted_price'].append(get_discount_price(new_soup))
        dict['original_price'].append(get_original_price(new_soup))
        dict['rating'].append(get_rating(new_soup))
        dict['box_item'].append(get_box_item(new_soup))
    
    flipkart_df = pd.DataFrame.from_dict(dict)
    flipkart_df['title'].replace('', np.nan, inplace=True)
    flipkart_df = flipkart_df.dropna(subset=['title'])
    flipkart_df.to_csv("flipkart_data.csv", header=True, index=False)

# %%
dict
# Out:
# {'title': ['APPLE iPhone 14 (Blue, 128 GB)',
#   'APPLE iPhone 12 (Blue, 64 GB)',
#   'APPLE iPhone 14 (Starlight, 128 GB)',
#   'APPLE iPhone 12 (Black, 64 GB)',
#   'APPLE iPhone 15 (Blue, 128 GB)',
#   'APPLE iPhone 14 Plus (Starlight, 128 GB)',
#   'APPLE iPhone 12 (Blue, 128 GB)',
#   'APPLE iPhone 14 (Midnight, 128 GB)',
#   'APPLE iPhone 12 (White, 64 GB)',
#   'APPLE iPhone 14 Plus (Blue, 128 GB)',
#   'APPLE iPhone 14 (Purple, 128 GB)',
#   'APPLE iPhone 15 (Black, 128 GB)',
#   'APPLE iPhone 14 (Midnight, 256 GB)',
#   'APPLE iPhone 14 (Starlight, 256 GB)',
#   'APPLE iPhone 14 (Purple, 256 GB)',
#   'APPLE iPhone 15 (Green, 128 GB)',
#   'APPLE iPhone 12 (Green, 64 GB)',
#   'APPLE iPhone 14 (Blue, 256 GB)',
#   'APPLE iPhone 14 Plus (Midnight, 128 GB)',
#   'APPLE iPhone 12 (White, 128 GB)',
#   'APPLE iPhone 15 (Pink, 128 GB)',
#   'APPLE iPhone 14 Plus (Purple, 128 GB)',
#   'APPLE iPhone 12 (Black, 128 GB)',
#   'APPLE iPhone 15 Plus (Blue, 128 GB)'],
#  'discounted_price': ['₹60,999',
#   '₹40,999',
#   '₹61,999',
#   '₹40,999',
#   '₹79,900',
#   '₹68,999',
#   '₹46,999',
#   '₹61,999',
#   '₹41,999',
#   '₹69,999',
#   '₹61,999',
#   '₹79,900',
#   '₹71,999',
#   '₹71,999',
#   '₹71,999',
#   '₹79,900',
#   '₹41,999',
#   '₹70,999',
#   '₹69,999',
#   '₹47,999',
#   '₹79,900',
#   '₹69,999',
#   '₹47,999',
#   '₹89,900'],
#  'original_price': ['₹69,900',
#   '₹49,900',
#   '₹69,900',
#   '₹49,900',
#   '',
#   '₹79,900',
#   '₹54,900',
#   '₹69,900',
#   '₹49,900',
#   '₹79,900',
#   '₹69,900',
#   '',
#   '₹79,900',
#   '₹79,900',
#   '₹79,900',
#   '',
#   '₹49,900',
#   '₹79,900',
#   '₹79,900',
#   '₹54,900',
#   '',
#   '₹79,900',
#   '₹54,900',
#   ''],
#  'rating': ['4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.6',
#   '4.7'],
#  'box_item': ['Handset, USB-C to Lightning Cable, Documentation',
#   'iPhone, USB-C to Lightning Cable, Documentation',
#   'Handset, USB-C to Lightning Cable, Documentation',
#   'iPhone, USB-C to Lightning Cable, Documentation',
#   'Handset, USB C Charge Cable (1m), Documentation',
#   'Handset, USB-C to Lightning Cable, Documentation',
#   'iPhone, USB-C to Lightning Cable, Documentation',
#   'Handset, USB-C to Lightning Cable, Documentation',
#   'iPhone, USB-C to Lightning Cable, Documentation',
#   'Handset, USB-C to Lightning Cable, Documentation',
#   'Handset, USB-C to Lightning Cable, Documentation',
#   'Handset, USB C Charge Cable (1m), Documentation',
#   'Handset, USB-C to Lightning Cable, Documentation',
#   'Handset, USB-C to Lightning Cable, Documentation',
#   'Handset, USB-C to Lightning Cable, Documentation',
#   'Handset, USB C Charge Cable (1m), Documentation',
#   'iPhone, USB-C to Lightning Cable, Documentation',
#   'Handset, USB-C to Lightning Cable, Documentation',
#   'Handset, USB-C to Lightning Cable, Documentation',
#   'iPhone, USB-C to Lightning Cable, Documentation',
#   'Handset, USB C Charge Cable (1m), Documentation',
#   'Handset, USB-C to Lightning Cable, Documentation',
#   'iPhone, USB-C to Lightning Cable, Documentation',
#   'Handset, USB C Charge Cable (1m), Documentation']}

# %%
flipkart_df
# Out:
#                                        title discounted_price original_price  \
# 0             APPLE iPhone 14 (Blue, 128 GB)          ₹60,999        ₹69,900
# 1              APPLE iPhone 12 (Blue, 64 GB)          ₹40,999        ₹49,900
# 2        APPLE iPhone 14 (Starlight, 128 GB)          ₹61,999        ₹69,900
# 3             APPLE iPhone 12 (Black, 64 GB)          ₹40,999        ₹49,900
# 4             APPLE iPhone 15 (Blue, 128 GB)          ₹79,900
# 5   APPLE iPhone 14 Plus (Starlight, 128 GB)          ₹68,999        ₹79,900
# 6             APPLE iPhone 12 (Blue, 128 GB)          ₹46,999        ₹54,900
# 7         APPLE iPhone 14 (Midnight, 128 GB)          ₹61,999        ₹69,900
# 8             APPLE iPhone 12 (White, 64 GB)          ₹41,999        ₹49,900
# 9        APPLE iPhone 14 Plus (Blue, 128 GB)          ₹69,999        ₹79,900
# 10          APPLE iPhone 14 (Purple, 128 GB)          ₹61,999        ₹69,900
# 11           APPLE iPhone 15 (Black, 128 GB)          ₹79,900
# 12        APPLE iPhone 14 (Midnight, 256 GB)          ₹71,999        ₹79,900
# 13       APPLE iPhone 14 (Starlight, 256 GB)          ₹71,999        ₹79,900
# 14          APPLE iPhone 14 (Purple, 256 GB)          ₹71,999        ₹79,900
# 15           APPLE iPhone 15 (Green, 128 GB)          ₹79,900
# 16            APPLE iPhone 12 (Green, 64 GB)          ₹41,999        ₹49,900
# 17            APPLE iPhone 14 (Blue, 256 GB)          ₹70,999        ₹79,900
# 18   APPLE iPhone 14 Plus (Midnight, 128 GB)          ₹69,999        ₹79,900
# 19           APPLE iPhone 12 (White, 128 GB)          ₹47,999        ₹54,900
# 20            APPLE iPhone 15 (Pink, 128 GB)          ₹79,900
# 21     APPLE iPhone 14 Plus (Purple, 128 GB)          ₹69,999        ₹79,900
# 22           APPLE iPhone 12 (Black, 128 GB)          ₹47,999        ₹54,900
# 23       APPLE iPhone 15 Plus (Blue, 128 GB)          ₹89,900
#
#    rating                                          box_item
# 0     4.6  Handset, USB-C to Lightning Cable, Documentation
# 1     4.6   iPhone, USB-C to Lightning Cable, Documentation
# 2     4.6  Handset, USB-C to Lightning Cable, Documentation
# 3     4.6   iPhone, USB-C to Lightning Cable, Documentation
# 4     4.6   Handset, USB C Charge Cable (1m), Documentation
# 5     4.6  Handset, USB-C to Lightning Cable, Documentation
# 6     4.6   iPhone, USB-C to Lightning Cable, Documentation
# 7     4.6  Handset, USB-C to Lightning Cable, Documentation
# 8     4.6   iPhone, USB-C to Lightning Cable, Documentation
# 9     4.6  Handset, USB-C to Lightning Cable, Documentation
# 10    4.6  Handset, USB-C to Lightning Cable, Documentation
# 11    4.6   Handset, USB C Charge Cable (1m), Documentation
# 12    4.6  Handset, USB-C to Lightning Cable, Documentation
# 13    4.6  Handset, USB-C to Lightning Cable, Documentation
# 14    4.6  Handset, USB-C to Lightning Cable, Documentation
# 15    4.6   Handset, USB C Charge Cable (1m), Documentation
# 16    4.6   iPhone, USB-C to Lightning Cable, Documentation
# 17    4.6  Handset, USB-C to Lightning Cable, Documentation
# 18    4.6  Handset, USB-C to Lightning Cable, Documentation
# 19    4.6   iPhone, USB-C to Lightning Cable, Documentation
# 20    4.6   Handset, USB C Charge Cable (1m), Documentation
# 21    4.6  Handset, USB-C to Lightning Cable, Documentation
# 22    4.6   iPhone, USB-C to Lightning Cable, Documentation
# 23    4.7   Handset, USB C Charge Cable (1m), Documentation
